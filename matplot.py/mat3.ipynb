# %% [markdown]
# plot bar

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
subs_len = np.arange(len(subs))
width = 0.4

# %%
plt.figure(figsize=(8,8))
subs = ['maths','english',"science"]
plt.subs = ['maths','english',"science"]
marks = [60,70,40]
marks2 = [50,60,90]
plt.bar(subs,marks,color = ['red','blue','orange'],width=0.5, edgecolor= 'black', linewidth = 5, linestyle='-.')
plt.bar(subs,marks2)
plt.yticks(np.arange(0,101,10))
plt.xlabel(subs)
plt.ylabel(marks)
plt.show()

# %%
plt.barh(subs,marks, color = ['red','blue','orange'])
plt.show()
